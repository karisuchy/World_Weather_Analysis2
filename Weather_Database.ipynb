# %%
# Unit 6 Challenge - Deliverable 1

# Import the dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

import gmaps
import requests

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# Import the datetime module from the datetime library.
from datetime import datetime

# Import the weather API key.
from config import weather_api_key

# Import the google API key
from config2 import g_key

# configure gmaps to use my google API key
gmaps.configure(api_key=g_key)

# %%
# Create a set of 2000 random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 746

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an endpoint URL for a city.
# city_url = url + "&q=" + "Boston"
# print(city_url)

# %%
# Make a 'Get' request for the city weather to test url before making full request
# city_weather = requests.get(city_url)
# city_weather

# %%
import requests
from datetime import datetime
from config import weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        # city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})
                        
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kudymkar
# Processing Record 2 of Set 1 | airai
# Processing Record 3 of Set 1 | chuy
# Processing Record 4 of Set 1 | ushuaia
# Processing Record 5 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 6 of Set 1 | teguldet
# Processing Record 7 of Set 1 | longyearbyen
# Processing Record 8 of Set 1 | port alfred
# Processing Record 9 of Set 1 | ayios matthaios
# City not found. Skipping...
# Processing Record 10 of Set 1 | saint-georges
# Processing Record 11 of Set 1 | busselton
# Processing Record 12 of Set 1 | rikitea
# Processing Record 13 of Set 1 | hobart
# Processing Record 14 of Set 1 | nome
# Processing Record 15 of Set 1 | cape town
# Processing Record 16 of Set 1 | barrow
# Processing Record 17 of Set 1 | san patricio
# Processing Record 18 of Set 1 | yellowknife
# Processing Record 19 of Set 1 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 20 of Set 1 | victoria
# Processing Record 21 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 22 of Set 1 | saskylakh
# Processing Record 23 of Set 1 | ebano
# City not found. Skipping...
# Processing Record 24 of Set 1 | nishihara
# Processing Record 25 of Set 1 | arraial do cabo
# Processing Record 26 of Set 1 | muisne
# Processing Record 27 of Set 1 | seymchan
# Processing Record 28 of Set 1 | atar
# Processing Record 29 of Set 1 | puro
# Processing Record 30 of Set 1 | thompson
# Processing Record 31 of Set 1 | banda aceh
# Processing Record 32 of Set 1 | mahebourg
# Processing Record 33 of Set 1 | tura
# Processing Record 34 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 35 of Set 1 | albany
# Processing Record 36 of Set 1 | south sioux city
# Processing Record 37 of Set 1 | upernavik
# Processing Record 38 of Set 1 | ponta do sol
# Processing Record 39 of Set 1 | hermanus
# Processing Record 40 of Set 1 | bethel
# Processing Record 41 of Set 1 | fortuna
# Processing Record 42 of Set 1 | vanimo
# Processing Record 43 of Set 1 | noumea
# Processing Record 44 of Set 1 | bredasdorp
# Processing Record 45 of Set 1 | jamestown
# Processing Record 46 of Set 1 | calamar
# Processing Record 47 of Set 1 | atuona
# Processing Record 48 of Set 1 | sterling
# Processing Record 49 of Set 1 | barbar
# City not found. Skipping...
# Processing Record 50 of Set 1 | kapaa
# Processing Record 1 of Set 2 | mataura
# Processing Record 2 of Set 2 | ancud
# Processing Record 3 of Set 2 | giyani
# Processing Record 4 of Set 2 | shenjiamen
# Processing Record 5 of Set 2 | hilo
# Processing Record 6 of Set 2 | pisco
# Processing Record 7 of Set 2 | pecos
# Processing Record 8 of Set 2 | avarua
# Processing Record 9 of Set 2 | tiksi
# Processing Record 10 of Set 2 | malwan
# City not found. Skipping...
# Processing Record 11 of Set 2 | ayame
# Processing Record 12 of Set 2 | yeppoon
# Processing Record 13 of Set 2 | vaini
# Processing Record 14 of Set 2 | fairbanks
# Processing Record 15 of Set 2 | lavrentiya
# Processing Record 16 of Set 2 | akranes
# Processing Record 17 of Set 2 | biltine
# Processing Record 18 of Set 2 | half moon bay
# Processing Record 19 of Set 2 | beringovskiy
# Processing Record 20 of Set 2 | tasiilaq
# Processing Record 21 of Set 2 | juneau
# Processing Record 22 of Set 2 | mackay
# Processing Record 23 of Set 2 | puerto ayora
# Processing Record 24 of Set 2 | garowe
# Processing Record 25 of Set 2 | doka
# Processing Record 26 of Set 2 | caravelas
# Processing Record 27 of Set 2 | novomalorossiyskaya
# Processing Record 28 of Set 2 | mitsamiouli
# Processing Record 29 of Set 2 | padang
# Processing Record 30 of Set 2 | punta arenas
# Processing Record 31 of Set 2 | grindavik
# Processing Record 32 of Set 2 | dahod
# Processing Record 33 of Set 2 | bluff
# Processing Record 34 of Set 2 | pacific grove
# Processing Record 35 of Set 2 | port hardy
# Processing Record 36 of Set 2 | dunedin
# Processing Record 37 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 38 of Set 2 | cherskiy
# Processing Record 39 of Set 2 | gilazi
# City not found. Skipping...
# Processing Record 40 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 41 of Set 2 | saint anthony
# Processing Record 42 of Set 2 | melk
# Processing Record 43 of Set 2 | nosivka
# Processing Record 44 of Set 2 | pevek
# Processing Record 45 of Set 2 | bundaberg
# Processing Record 46 of Set 2 | lebu
# Processing Record 47 of Set 2 | kununurra
# Processing Record 48 of Set 2 | vancouver
# Processing Record 49 of Set 2 | hwange
# Processing Record 50 of Set 2 | erenhot
# Processing Record 1 of Set 3 | fairlie
# Processing Record 2 of Set 3 | bengkulu
# Processing Record 3 of Set 3 | fukue
# Processing Record 4 of Set 3 | shirokiy
# Processing Record 5 of Set 3 | okhotsk
# Processing Record 6 of Set 3 | saint-pierre
# Processing Record 7 of Set 3 | aykhal
# Processing Record 8 of Set 3 | saint george
# Processing Record 9 of Set 3 | nizhniy tsasuchey
# Processing Record 10 of Set 3 | yining
# Processing Record 11 of Set 3 | areosa
# Processing Record 12 of Set 3 | opuwo
# Processing Record 13 of Set 3 | kaitangata
# Processing Record 14 of Set 3 | pastavy
# Processing Record 15 of Set 3 | sahrak
# City not found. Skipping...
# Processing Record 16 of Set 3 | codrington
# Processing Record 17 of Set 3 | vaitape
# Processing Record 18 of Set 3 | netrakona
# Processing Record 19 of Set 3 | sao filipe
# Processing Record 20 of Set 3 | yulara
# Processing Record 21 of Set 3 | butaritari
# Processing Record 22 of Set 3 | zamboanga
# Processing Record 23 of Set 3 | saint-philippe
# Processing Record 24 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 25 of Set 3 | kyzyl-suu
# Processing Record 26 of Set 3 | tirumala
# Processing Record 27 of Set 3 | novikovo
# Processing Record 28 of Set 3 | sirohi
# Processing Record 29 of Set 3 | pangody
# Processing Record 30 of Set 3 | sao joao da barra
# Processing Record 31 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 32 of Set 3 | rovaniemi
# Processing Record 33 of Set 3 | hailar
# Processing Record 34 of Set 3 | nikolskoye
# Processing Record 35 of Set 3 | aranos
# Processing Record 36 of Set 3 | matara
# Processing Record 37 of Set 3 | gravdal
# Processing Record 38 of Set 3 | souillac
# Processing Record 39 of Set 3 | canon city
# Processing Record 40 of Set 3 | viiratsi
# Processing Record 41 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 42 of Set 3 | ahipara
# Processing Record 43 of Set 3 | san policarpo
# Processing Record 44 of Set 3 | salalah
# Processing Record 45 of Set 3 | iqaluit
# Processing Record 46 of Set 3 | piacabucu
# Processing Record 47 of Set 3 | port elizabeth
# Processing Record 48 of Set 3 | namibe
# Processing Record 49 of Set 3 | new norfolk
# Processing Record 50 of Set 3 | stoyba
# City not found. Skipping...
# Processing Record 1 of Set 4 | katangli
# Processing Record 2 of Set 4 | tuktoyaktuk
# Processing Record 3 of Set 4 | praia da vitoria
# Processing Record 4 of Set 4 | budogoshch
# Processing Record 5 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 6 of Set 4 | snezhnogorsk
# Processing Record 7 of Set 4 | sitka
# Processing Record 8 of Set 4 | novokayakent
# Processing Record 9 of Set 4 | kodiak
# Processing Record 10 of Set 4 | esperance
# Processing Record 11 of Set 4 | keller
# Processing Record 12 of Set 4 | klaksvik
# Processing Record 13 of Set 4 | waipawa
# Processing Record 14 of Set 4 | acaponeta
# Processing Record 15 of Set 4 | timmins
# Processing Record 16 of Set 4 | hasaki
# Processing Record 17 of Set 4 | cidreira
# Processing Record 18 of Set 4 | faanui
# Processing Record 19 of Set 4 | utamysh
# Processing Record 20 of Set 4 | bambous virieux
# Processing Record 21 of Set 4 | hambantota
# Processing Record 22 of Set 4 | burica
# City not found. Skipping...
# Processing Record 23 of Set 4 | biryusinsk
# Processing Record 24 of Set 4 | la union
# Processing Record 25 of Set 4 | east london
# Processing Record 26 of Set 4 | vao
# Processing Record 27 of Set 4 | mayo
# Processing Record 28 of Set 4 | qaanaaq
# Processing Record 29 of Set 4 | constitucion
# Processing Record 30 of Set 4 | bonthe
# Processing Record 31 of Set 4 | ngaoundere
# Processing Record 32 of Set 4 | rio grande
# Processing Record 33 of Set 4 | omsukchan
# Processing Record 34 of Set 4 | tabou
# Processing Record 35 of Set 4 | harper
# Processing Record 36 of Set 4 | aklavik
# Processing Record 37 of Set 4 | sorland
# Processing Record 38 of Set 4 | bani
# Processing Record 39 of Set 4 | williston
# Processing Record 40 of Set 4 | dikson
# Processing Record 41 of Set 4 | dolbeau
# City not found. Skipping...
# Processing Record 42 of Set 4 | endicott
# Processing Record 43 of Set 4 | aswan
# Processing Record 44 of Set 4 | tumkur
# Processing Record 45 of Set 4 | halalo
# City not found. Skipping...
# Processing Record 46 of Set 4 | portland
# Processing Record 47 of Set 4 | todos santos
# Processing Record 48 of Set 4 | bakchar
# Processing Record 49 of Set 4 | alofi
# Processing Record 50 of Set 4 | rawson
# Processing Record 1 of Set 5 | bud
# Processing Record 2 of Set 5 | green river
# Processing Record 3 of Set 5 | vila velha
# Processing Record 4 of Set 5 | banjar
# Processing Record 5 of Set 5 | broken hill
# Processing Record 6 of Set 5 | castro
# Processing Record 7 of Set 5 | auki
# Processing Record 8 of Set 5 | leningradskiy
# Processing Record 9 of Set 5 | mar del plata
# Processing Record 10 of Set 5 | cockburn town
# Processing Record 11 of Set 5 | letlhakane
# Processing Record 12 of Set 5 | leua
# Processing Record 13 of Set 5 | beyneu
# Processing Record 14 of Set 5 | katiola
# Processing Record 15 of Set 5 | jiddah
# City not found. Skipping...
# Processing Record 16 of Set 5 | lata
# Processing Record 17 of Set 5 | slavuta
# Processing Record 18 of Set 5 | imeni poliny osipenko
# Processing Record 19 of Set 5 | ilulissat
# Processing Record 20 of Set 5 | micheweni
# Processing Record 21 of Set 5 | hihifo
# City not found. Skipping...
# Processing Record 22 of Set 5 | clyde river
# Processing Record 23 of Set 5 | novyy urengoy
# Processing Record 24 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 25 of Set 5 | petatlan
# Processing Record 26 of Set 5 | haapu
# City not found. Skipping...
# Processing Record 27 of Set 5 | garden city
# Processing Record 28 of Set 5 | berlevag
# Processing Record 29 of Set 5 | saldanha
# Processing Record 30 of Set 5 | samalaeulu
# City not found. Skipping...
# Processing Record 31 of Set 5 | nouadhibou
# Processing Record 32 of Set 5 | krasnoselkup
# Processing Record 33 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 34 of Set 5 | nagyhegyes
# Processing Record 35 of Set 5 | kahului
# Processing Record 36 of Set 5 | kalmunai
# Processing Record 37 of Set 5 | bathsheba
# Processing Record 38 of Set 5 | alice springs
# Processing Record 39 of Set 5 | carballo
# Processing Record 40 of Set 5 | southbridge
# Processing Record 41 of Set 5 | forio
# Processing Record 42 of Set 5 | telma
# Processing Record 43 of Set 5 | jijiga
# Processing Record 44 of Set 5 | panguiranan
# Processing Record 45 of Set 5 | norman wells
# Processing Record 46 of Set 5 | luderitz
# Processing Record 47 of Set 5 | dingzhou
# Processing Record 48 of Set 5 | najran
# Processing Record 49 of Set 5 | cocobeach
# Processing Record 50 of Set 5 | otjiwarongo
# Processing Record 1 of Set 6 | provideniya
# Processing Record 2 of Set 6 | constantine
# Processing Record 3 of Set 6 | bababe
# City not found. Skipping...
# Processing Record 4 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 5 of Set 6 | shalinskoye
# Processing Record 6 of Set 6 | san marcos
# Processing Record 7 of Set 6 | ibra
# Processing Record 8 of Set 6 | olafsvik
# Processing Record 9 of Set 6 | ormos korthiou
# City not found. Skipping...
# Processing Record 10 of Set 6 | talnakh
# Processing Record 11 of Set 6 | mayna
# Processing Record 12 of Set 6 | bekhtery
# Processing Record 13 of Set 6 | nanma
# Processing Record 14 of Set 6 | wagrowiec
# Processing Record 15 of Set 6 | yumen
# Processing Record 16 of Set 6 | celestun
# Processing Record 17 of Set 6 | mayor pablo lagerenza
# Processing Record 18 of Set 6 | lensk
# Processing Record 19 of Set 6 | melipilla
# Processing Record 20 of Set 6 | gobabis
# Processing Record 21 of Set 6 | san nicolas
# Processing Record 22 of Set 6 | carnarvon
# Processing Record 23 of Set 6 | general roca
# Processing Record 24 of Set 6 | torbay
# Processing Record 25 of Set 6 | nam tha
# City not found. Skipping...
# Processing Record 26 of Set 6 | san vicente
# Processing Record 27 of Set 6 | chihuahua
# Processing Record 28 of Set 6 | qaqortoq
# Processing Record 29 of Set 6 | pangkalanbuun
# Processing Record 30 of Set 6 | yar-sale
# Processing Record 31 of Set 6 | muhos
# Processing Record 32 of Set 6 | linxia
# Processing Record 33 of Set 6 | isangel
# Processing Record 34 of Set 6 | mount isa
# Processing Record 35 of Set 6 | boa vista
# Processing Record 36 of Set 6 | kaeng khlo
# City not found. Skipping...
# Processing Record 37 of Set 6 | oistins
# Processing Record 38 of Set 6 | severo-kurilsk
# Processing Record 39 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 40 of Set 6 | ningxiang
# Processing Record 41 of Set 6 | geraldton
# Processing Record 42 of Set 6 | srednekolymsk
# Processing Record 43 of Set 6 | kisanga
# Processing Record 44 of Set 6 | nuuk
# Processing Record 45 of Set 6 | kosino
# Processing Record 46 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 47 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 48 of Set 6 | niquelandia
# Processing Record 49 of Set 6 | port-de-paix
# City not found. Skipping...
# Processing Record 50 of Set 6 | kashi
# Processing Record 1 of Set 7 | kavieng
# Processing Record 2 of Set 7 | taoudenni
# Processing Record 3 of Set 7 | khatanga
# Processing Record 4 of Set 7 | riyadh
# Processing Record 5 of Set 7 | tyazhinskiy
# Processing Record 6 of Set 7 | mangan
# Processing Record 7 of Set 7 | barreirinhas
# Processing Record 8 of Set 7 | ambilobe
# Processing Record 9 of Set 7 | atlantic city
# Processing Record 10 of Set 7 | luwuk
# Processing Record 11 of Set 7 | atbasar
# Processing Record 12 of Set 7 | georgetown
# Processing Record 13 of Set 7 | mazamitla
# Processing Record 14 of Set 7 | buin
# Processing Record 15 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 16 of Set 7 | hami
# Processing Record 17 of Set 7 | goderich
# Processing Record 18 of Set 7 | skjervoy
# Processing Record 19 of Set 7 | lagoa
# Processing Record 20 of Set 7 | hearst
# Processing Record 21 of Set 7 | george town
# Processing Record 22 of Set 7 | te anau
# Processing Record 23 of Set 7 | udachnyy
# Processing Record 24 of Set 7 | qandala
# Processing Record 25 of Set 7 | iisalmi
# Processing Record 26 of Set 7 | bitung
# Processing Record 27 of Set 7 | katsuura
# Processing Record 28 of Set 7 | preobrazheniye
# Processing Record 29 of Set 7 | warwick
# Processing Record 30 of Set 7 | tevaitoa
# Processing Record 31 of Set 7 | sao miguel do tapuio
# Processing Record 32 of Set 7 | pitimbu
# Processing Record 33 of Set 7 | pyapon
# Processing Record 34 of Set 7 | faya
# Processing Record 35 of Set 7 | san juan
# Processing Record 36 of Set 7 | jacareacanga
# Processing Record 37 of Set 7 | payson
# Processing Record 38 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 39 of Set 7 | metro
# Processing Record 40 of Set 7 | kanigoro
# Processing Record 41 of Set 7 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 42 of Set 7 | zamboanguita
# Processing Record 43 of Set 7 | contamana
# Processing Record 44 of Set 7 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 45 of Set 7 | tuatapere
# Processing Record 46 of Set 7 | ust-nera
# Processing Record 47 of Set 7 | yangambi
# Processing Record 48 of Set 7 | pringsewu
# Processing Record 49 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 50 of Set 7 | port hedland
# Processing Record 1 of Set 8 | pioner
# Processing Record 2 of Set 8 | kamenka
# Processing Record 3 of Set 8 | san rafael
# Processing Record 4 of Set 8 | qom
# Processing Record 5 of Set 8 | amapa
# Processing Record 6 of Set 8 | manica
# Processing Record 7 of Set 8 | guerrero negro
# Processing Record 8 of Set 8 | songea
# Processing Record 9 of Set 8 | salitral
# Processing Record 10 of Set 8 | fallon
# Processing Record 11 of Set 8 | batticaloa
# Processing Record 12 of Set 8 | gberia fotombu
# Processing Record 13 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 14 of Set 8 | chapais
# Processing Record 15 of Set 8 | shache
# Processing Record 16 of Set 8 | mvuma
# Processing Record 17 of Set 8 | hinatuan
# Processing Record 18 of Set 8 | tual
# Processing Record 19 of Set 8 | mayumba
# Processing Record 20 of Set 8 | kautokeino
# Processing Record 21 of Set 8 | toamasina
# Processing Record 22 of Set 8 | lorengau
# Processing Record 23 of Set 8 | touros
# Processing Record 24 of Set 8 | dalbandin
# Processing Record 25 of Set 8 | valpacos
# Processing Record 26 of Set 8 | hay river
# Processing Record 27 of Set 8 | ribeira grande
# Processing Record 28 of Set 8 | aksay
# Processing Record 29 of Set 8 | arman
# Processing Record 30 of Set 8 | nelson bay
# Processing Record 31 of Set 8 | pout
# Processing Record 32 of Set 8 | laguna
# Processing Record 33 of Set 8 | kruisfontein
# Processing Record 34 of Set 8 | mirabad
# Processing Record 35 of Set 8 | palu
# Processing Record 36 of Set 8 | namatanai
# Processing Record 37 of Set 8 | cabo san lucas
# Processing Record 38 of Set 8 | bentiu
# Processing Record 39 of Set 8 | huarmey
# Processing Record 40 of Set 8 | aguas vermelhas
# Processing Record 41 of Set 8 | lagos
# Processing Record 42 of Set 8 | pingliang
# Processing Record 43 of Set 8 | mehamn
# Processing Record 44 of Set 8 | tefe
# Processing Record 45 of Set 8 | paramonga
# Processing Record 46 of Set 8 | barawe
# City not found. Skipping...
# Processing Record 47 of Set 8 | zlitan
# Processing Record 48 of Set 8 | vrbno pod pradedem
# Processing Record 49 of Set 8 | kollumerland
# City not found. Skipping...
# Processing Record 50 of Set 8 | lazaro cardenas
# Processing Record 1 of Set 9 | jocotepec
# Processing Record 2 of Set 9 | silyanah
# City not found. Skipping...
# Processing Record 3 of Set 9 | hithadhoo
# Processing Record 4 of Set 9 | huilong
# Processing Record 5 of Set 9 | mareeba
# Processing Record 6 of Set 9 | blythe
# Processing Record 7 of Set 9 | ostrovnoy
# Processing Record 8 of Set 9 | avera
# Processing Record 9 of Set 9 | tilichiki
# Processing Record 10 of Set 9 | beloha
# Processing Record 11 of Set 9 | tsogni
# Processing Record 12 of Set 9 | kushiro
# Processing Record 13 of Set 9 | kerteh
# City not found. Skipping...
# Processing Record 14 of Set 9 | makakilo city
# Processing Record 15 of Set 9 | socorro
# Processing Record 16 of Set 9 | coihaique
# Processing Record 17 of Set 9 | waw
# Processing Record 18 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 19 of Set 9 | charters towers
# Processing Record 20 of Set 9 | yanan
# City not found. Skipping...
# Processing Record 21 of Set 9 | shelburne
# Processing Record 22 of Set 9 | necochea
# Processing Record 23 of Set 9 | ilinge
# Processing Record 24 of Set 9 | bargal
# City not found. Skipping...
# Processing Record 25 of Set 9 | sur
# Processing Record 26 of Set 9 | chokurdakh
# Processing Record 27 of Set 9 | zharkent
# Processing Record 28 of Set 9 | high prairie
# Processing Record 29 of Set 9 | lafiagi
# Processing Record 30 of Set 9 | borogontsy
# Processing Record 31 of Set 9 | nioro
# Processing Record 32 of Set 9 | fare
# Processing Record 33 of Set 9 | barranca
# Processing Record 34 of Set 9 | cortez
# Processing Record 35 of Set 9 | careiro da varzea
# Processing Record 36 of Set 9 | kralendijk
# Processing Record 37 of Set 9 | llangefni
# Processing Record 38 of Set 9 | lower hutt
# Processing Record 39 of Set 9 | kropotkin
# Processing Record 40 of Set 9 | arroyo
# Processing Record 41 of Set 9 | lompoc
# Processing Record 42 of Set 9 | nizhneyansk
# City not found. Skipping...
# Processing Record 43 of Set 9 | santa vitoria do palmar
# Processing Record 44 of Set 9 | san andres
# Processing Record 45 of Set 9 | roald
# Processing Record 46 of Set 9 | santiago
# Processing Record 47 of Set 9 | bahia blanca
# Processing Record 48 of Set 9 | lannion
# Processing Record 49 of Set 9 | urucara
# Processing Record 50 of Set 9 | arlit
# Processing Record 1 of Set 10 | yelizovo
# Processing Record 2 of Set 10 | korla
# Processing Record 3 of Set 10 | malartic
# Processing Record 4 of Set 10 | chicama
# Processing Record 5 of Set 10 | taman
# Processing Record 6 of Set 10 | taseyevo
# Processing Record 7 of Set 10 | coquimbo
# Processing Record 8 of Set 10 | lewisporte
# Processing Record 9 of Set 10 | moore
# Processing Record 10 of Set 10 | port macquarie
# Processing Record 11 of Set 10 | bilma
# Processing Record 12 of Set 10 | cairns
# Processing Record 13 of Set 10 | garmsar
# Processing Record 14 of Set 10 | samarai
# Processing Record 15 of Set 10 | wulanhaote
# City not found. Skipping...
# Processing Record 16 of Set 10 | astana
# Processing Record 17 of Set 10 | shasta lake
# Processing Record 18 of Set 10 | bose
# Processing Record 19 of Set 10 | neuquen
# Processing Record 20 of Set 10 | gari
# Processing Record 21 of Set 10 | posse
# Processing Record 22 of Set 10 | kumbo
# Processing Record 23 of Set 10 | formoso do araguaia
# City not found. Skipping...
# Processing Record 24 of Set 10 | bodden town
# Processing Record 25 of Set 10 | camacha
# Processing Record 26 of Set 10 | langub
# Processing Record 27 of Set 10 | hualmay
# Processing Record 28 of Set 10 | phangnga
# Processing Record 29 of Set 10 | narsaq
# Processing Record 30 of Set 10 | bubaque
# Processing Record 31 of Set 10 | aksha
# Processing Record 32 of Set 10 | onguday
# Processing Record 33 of Set 10 | harsum
# Processing Record 34 of Set 10 | moree
# Processing Record 35 of Set 10 | sorvag
# City not found. Skipping...
# Processing Record 36 of Set 10 | krosno
# Processing Record 37 of Set 10 | lamu
# Processing Record 38 of Set 10 | aflu
# City not found. Skipping...
# Processing Record 39 of Set 10 | college station
# Processing Record 40 of Set 10 | richards bay
# Processing Record 41 of Set 10 | tabas
# Processing Record 42 of Set 10 | aksarka
# Processing Record 43 of Set 10 | nizhniy kuranakh
# Processing Record 44 of Set 10 | seinajoki
# Processing Record 45 of Set 10 | bijie
# Processing Record 46 of Set 10 | quatre cocos
# Processing Record 47 of Set 10 | kabanjahe
# Processing Record 48 of Set 10 | boca do acre
# Processing Record 49 of Set 10 | oranjemund
# Processing Record 50 of Set 10 | natal
# Processing Record 1 of Set 11 | powell river
# Processing Record 2 of Set 11 | vilhena
# Processing Record 3 of Set 11 | sokna
# Processing Record 4 of Set 11 | haines junction
# Processing Record 5 of Set 11 | bairiki
# Processing Record 6 of Set 11 | karoi
# Processing Record 7 of Set 11 | mabaruma
# Processing Record 8 of Set 11 | negombo
# Processing Record 9 of Set 11 | caiaponia
# Processing Record 10 of Set 11 | shitanjing
# Processing Record 11 of Set 11 | durban
# Processing Record 12 of Set 11 | yerbogachen
# Processing Record 13 of Set 11 | chunskiy
# Processing Record 14 of Set 11 | cumaribo
# City not found. Skipping...
# Processing Record 15 of Set 11 | eganville
# Processing Record 16 of Set 11 | alyangula
# Processing Record 17 of Set 11 | san juan de la maguana
# Processing Record 18 of Set 11 | hachinohe
# Processing Record 19 of Set 11 | san matias
# Processing Record 20 of Set 11 | lucea
# Processing Record 21 of Set 11 | bonavista
# Processing Record 22 of Set 11 | kudahuvadhoo
# Processing Record 23 of Set 11 | bauru
# Processing Record 24 of Set 11 | votkinsk
# Processing Record 25 of Set 11 | flinders
# Processing Record 26 of Set 11 | sabha
# Processing Record 27 of Set 11 | saint-augustin
# Processing Record 28 of Set 11 | port lincoln
# Processing Record 29 of Set 11 | san quintin
# Processing Record 30 of Set 11 | egvekinot
# Processing Record 31 of Set 11 | wamba
# Processing Record 32 of Set 11 | bandundu
# Processing Record 33 of Set 11 | nueva guinea
# Processing Record 34 of Set 11 | nizip
# Processing Record 35 of Set 11 | churapcha
# Processing Record 36 of Set 11 | birjand
# Processing Record 37 of Set 11 | victor harbor
# Processing Record 38 of Set 11 | port blair
# Processing Record 39 of Set 11 | dingle
# Processing Record 40 of Set 11 | esmeraldas
# Processing Record 41 of Set 11 | xixiang
# Processing Record 42 of Set 11 | kanye
# Processing Record 43 of Set 11 | jakar
# Processing Record 44 of Set 11 | kulhudhuffushi
# Processing Record 45 of Set 11 | sillamae
# Processing Record 46 of Set 11 | doha
# Processing Record 47 of Set 11 | novyy yarychiv
# Processing Record 48 of Set 11 | saint-louis
# Processing Record 49 of Set 11 | asau
# Processing Record 50 of Set 11 | boguchar
# Processing Record 1 of Set 12 | quimper
# Processing Record 2 of Set 12 | bali chak
# Processing Record 3 of Set 12 | brazzaville
# Processing Record 4 of Set 12 | bantogon
# Processing Record 5 of Set 12 | ritchie
# Processing Record 6 of Set 12 | ugoofaaru
# Processing Record 7 of Set 12 | sambava
# Processing Record 8 of Set 12 | maniitsoq
# Processing Record 9 of Set 12 | gurskoye
# City not found. Skipping...
# Processing Record 10 of Set 12 | cerro gordo
# Processing Record 11 of Set 12 | poum
# Processing Record 12 of Set 12 | vila franca do campo
# Processing Record 13 of Set 12 | baghdad
# Processing Record 14 of Set 12 | bolshaya dzhalga
# Processing Record 15 of Set 12 | marquette
# Processing Record 16 of Set 12 | ust-kut
# Processing Record 17 of Set 12 | rodrigues alves
# Processing Record 18 of Set 12 | tautira
# Processing Record 19 of Set 12 | tommot
# Processing Record 20 of Set 12 | baruun-urt
# Processing Record 21 of Set 12 | kyshtovka
# Processing Record 22 of Set 12 | sheboygan
# Processing Record 23 of Set 12 | rapid city
# Processing Record 24 of Set 12 | carroll
# Processing Record 25 of Set 12 | iwanai
# Processing Record 26 of Set 12 | khonuu
# City not found. Skipping...
# Processing Record 27 of Set 12 | hirara
# Processing Record 28 of Set 12 | lakes entrance
# Processing Record 29 of Set 12 | janakpur
# Processing Record 30 of Set 12 | sulangan
# Processing Record 31 of Set 12 | cayenne
# Processing Record 32 of Set 12 | batsfjord
# Processing Record 33 of Set 12 | irbil
# Processing Record 34 of Set 12 | daru
# Processing Record 35 of Set 12 | camapua
# Processing Record 36 of Set 12 | khandyga
# Processing Record 37 of Set 12 | meulaboh
# Processing Record 38 of Set 12 | mulanje
# Processing Record 39 of Set 12 | san cristobal
# Processing Record 40 of Set 12 | innisfail
# Processing Record 41 of Set 12 | la ronge
# Processing Record 42 of Set 12 | lingao
# Processing Record 43 of Set 12 | ghanzi
# Processing Record 44 of Set 12 | alta floresta
# Processing Record 45 of Set 12 | manggar
# Processing Record 46 of Set 12 | mount gambier
# Processing Record 47 of Set 12 | karratha
# Processing Record 48 of Set 12 | longlac
# City not found. Skipping...
# Processing Record 49 of Set 12 | kandrian
# Processing Record 50 of Set 12 | karla
# Processing Record 1 of Set 13 | xichang
# Processing Record 2 of Set 13 | los llanos de aridane
# Processing Record 3 of Set 13 | eufaula
# Processing Record 4 of Set 13 | kaili
# Processing Record 5 of Set 13 | thinadhoo
# Processing Record 6 of Set 13 | seoul
# Processing Record 7 of Set 13 | kasongo-lunda
# Processing Record 8 of Set 13 | omboue
# Processing Record 9 of Set 13 | forestville
# Processing Record 10 of Set 13 | casablanca
# Processing Record 11 of Set 13 | dzhusaly
# City not found. Skipping...
# Processing Record 12 of Set 13 | chagda
# City not found. Skipping...
# Processing Record 13 of Set 13 | kerema
# Processing Record 14 of Set 13 | ranot
# Processing Record 15 of Set 13 | goure
# Processing Record 16 of Set 13 | turka
# Processing Record 17 of Set 13 | cuamba
# Processing Record 18 of Set 13 | presidencia roque saenz pena
# Processing Record 19 of Set 13 | kuningan
# Processing Record 20 of Set 13 | yaan
# Processing Record 21 of Set 13 | akdepe
# Processing Record 22 of Set 13 | kathmandu
# Processing Record 23 of Set 13 | nadvoitsy
# Processing Record 24 of Set 13 | myanaung
# Processing Record 25 of Set 13 | axim
# Processing Record 26 of Set 13 | north bend
# Processing Record 27 of Set 13 | mutsu
# Processing Record 28 of Set 13 | moyo
# Processing Record 29 of Set 13 | balabac
# Processing Record 30 of Set 13 | suraabad
# Processing Record 31 of Set 13 | sandakan
# Processing Record 32 of Set 13 | pederneiras
# Processing Record 33 of Set 13 | clarence town
# Processing Record 34 of Set 13 | kutno
# Processing Record 35 of Set 13 | miri
# Processing Record 36 of Set 13 | a
# City not found. Skipping...
# Processing Record 37 of Set 13 | huangpi
# Processing Record 38 of Set 13 | salisbury
# Processing Record 39 of Set 13 | wewak
# Processing Record 40 of Set 13 | tecoanapa
# Processing Record 41 of Set 13 | buchanan
# Processing Record 42 of Set 13 | saa
# Processing Record 43 of Set 13 | anori
# Processing Record 44 of Set 13 | petrolandia
# City not found. Skipping...
# Processing Record 45 of Set 13 | ulladulla
# Processing Record 46 of Set 13 | aragona
# Processing Record 47 of Set 13 | villazon
# Processing Record 48 of Set 13 | merauke
# Processing Record 49 of Set 13 | karamay
# City not found. Skipping...
# Processing Record 50 of Set 13 | catamarca
# Processing Record 1 of Set 14 | acapulco
# Processing Record 2 of Set 14 | xushan
# Processing Record 3 of Set 14 | kolokani
# Processing Record 4 of Set 14 | ahuimanu
# Processing Record 5 of Set 14 | macae
# Processing Record 6 of Set 14 | caohai
# Processing Record 7 of Set 14 | jalu
# Processing Record 8 of Set 14 | hobyo
# Processing Record 9 of Set 14 | husavik
# Processing Record 10 of Set 14 | alta gracia
# Processing Record 11 of Set 14 | madison
# Processing Record 12 of Set 14 | at-bashi
# Processing Record 13 of Set 14 | malakal
# Processing Record 14 of Set 14 | lake havasu city
# Processing Record 15 of Set 14 | djenne
# Processing Record 16 of Set 14 | great yarmouth
# Processing Record 17 of Set 14 | tshikapa
# Processing Record 18 of Set 14 | okha
# Processing Record 19 of Set 14 | boundiali
# Processing Record 20 of Set 14 | behshahr
# Processing Record 21 of Set 14 | dolores
# Processing Record 22 of Set 14 | benjamin hill
# Processing Record 23 of Set 14 | aketi
# Processing Record 24 of Set 14 | baykit
# Processing Record 25 of Set 14 | biak
# Processing Record 26 of Set 14 | whitianga
# Processing Record 27 of Set 14 | balsas
# Processing Record 28 of Set 14 | farso
# Processing Record 29 of Set 14 | kaupanger
# Processing Record 30 of Set 14 | moindou
# Processing Record 31 of Set 14 | simao dias
# Processing Record 32 of Set 14 | hundorp
# Processing Record 33 of Set 14 | belmonte
# Processing Record 34 of Set 14 | nouakchott
# Processing Record 35 of Set 14 | karkaralinsk
# City not found. Skipping...
# Processing Record 36 of Set 14 | glenwood springs
# Processing Record 37 of Set 14 | saint-ambroise
# Processing Record 38 of Set 14 | port-gentil
# Processing Record 39 of Set 14 | nalut
# Processing Record 40 of Set 14 | honningsvag
# Processing Record 41 of Set 14 | ingham
# Processing Record 42 of Set 14 | ajdabiya
# Processing Record 43 of Set 14 | evensk
# Processing Record 44 of Set 14 | sarkand
# Processing Record 45 of Set 14 | gaya
# Processing Record 46 of Set 14 | mangai
# Processing Record 47 of Set 14 | college
# Processing Record 48 of Set 14 | colac
# Processing Record 49 of Set 14 | cururupu
# Processing Record 50 of Set 14 | russell
# Processing Record 1 of Set 15 | korcula
# Processing Record 2 of Set 15 | puteyets
# Processing Record 3 of Set 15 | yara
# Processing Record 4 of Set 15 | adrar
# Processing Record 5 of Set 15 | vastervik
# City not found. Skipping...
# Processing Record 6 of Set 15 | podlesnoye
# Processing Record 7 of Set 15 | yebaishou
# Processing Record 8 of Set 15 | shimoda
# Processing Record 9 of Set 15 | deputatskiy
# Processing Record 10 of Set 15 | sidi ali
# Processing Record 11 of Set 15 | bosobolo
# Processing Record 12 of Set 15 | dzhebariki-khaya
# Processing Record 13 of Set 15 | linjiang
# Processing Record 14 of Set 15 | bajo baudo
# City not found. Skipping...
# Processing Record 15 of Set 15 | fushun
# Processing Record 16 of Set 15 | severodvinsk
# Processing Record 17 of Set 15 | farmington
# Processing Record 18 of Set 15 | hervey bay
# Processing Record 19 of Set 15 | ledyard
# Processing Record 20 of Set 15 | korbach
# Processing Record 21 of Set 15 | sao luiz gonzaga
# Processing Record 22 of Set 15 | nanortalik
# Processing Record 23 of Set 15 | manacapuru
# Processing Record 24 of Set 15 | rio gallegos
# Processing Record 25 of Set 15 | monrovia
# Processing Record 26 of Set 15 | zhezkazgan
# Processing Record 27 of Set 15 | brae
# Processing Record 28 of Set 15 | bowen
# Processing Record 29 of Set 15 | burnie
# Processing Record 30 of Set 15 | hofn
# Processing Record 31 of Set 15 | venado tuerto
# Processing Record 32 of Set 15 | gaffney
# Processing Record 33 of Set 15 | mosetse
# Processing Record 34 of Set 15 | buraydah
# Processing Record 35 of Set 15 | benicarlo
# Processing Record 36 of Set 15 | palimbang
# Processing Record 37 of Set 15 | kupang
# Processing Record 38 of Set 15 | manavalakurichi
# Processing Record 39 of Set 15 | obra
# Processing Record 40 of Set 15 | cabra
# Processing Record 41 of Set 15 | virginia beach
# Processing Record 42 of Set 15 | maceio
# Processing Record 43 of Set 15 | ganzhou
# Processing Record 44 of Set 15 | alibag
# Processing Record 45 of Set 15 | xining
# Processing Record 46 of Set 15 | solnechnyy
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 682

# %%
city_data_df = pd.DataFrame(city_data)

# %%
city_data_df.head()
# Out:
#        City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Kudymkar      RU  59.0173   54.6560     40.75        94         100
# 1     Airai      TL  -8.9266  125.4092     64.09        89          99
# 2      Chuy      UY -33.6971  -53.4616     71.19        73          99
# 3   Ushuaia      AR -54.8000  -68.3000     46.06        53           0
# 4  Teguldet      RU  57.3064   88.1667     25.20        61          53
#
#    Wind Speed Current Description
# 0       10.80     overcast clouds
# 1        0.16     overcast clouds
# 2       14.52     overcast clouds
# 3       19.57           clear sky
# 4       10.18       broken clouds

# %%
# explort to csv
output_data_file = "WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label="City_ID")
